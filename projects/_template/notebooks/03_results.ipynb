# %% [markdown]
# # 03 - Results & Visualization
#
# Visualize and present final results.
#
# **Tasks:**
# - Load trained models and results
# - Create visualizations
# - Generate summary metrics
# - Save figures for reports/papers

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import joblib
import json

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# ## Load Data and Models

# %%
# Load processed data
data = np.load('../data/processed/embeddings.npz')
X = data['embeddings']
# y = data['labels']

# Load trained model
# clf = joblib.load('../models/my_model.pkl')

# %% [markdown]
# ## Visualizations
#
# **TODO**: Create your visualizations here.

# %%
# Example: Confusion matrix
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test, y_pred)

# plt.figure(figsize=(10, 8))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.title('Confusion Matrix')
# plt.ylabel('True Label')
# plt.xlabel('Predicted Label')
# plt.tight_layout()
# plt.savefig('../results/figures/confusion_matrix.png', dpi=300, bbox_inches='tight')
# plt.show()

# %%
# Example: Feature importance
# importances = clf.feature_importances_

# plt.figure(figsize=(10, 6))
# plt.bar(range(len(importances)), importances)
# plt.title('Feature Importance')
# plt.xlabel('Feature Index')
# plt.ylabel('Importance')
# plt.savefig('../results/figures/feature_importance.png', dpi=300, bbox_inches='tight')
# plt.show()

# %%
# Example: Embedding visualization (UMAP/t-SNE)
# from sklearn.manifold import TSNE

# tsne = TSNE(n_components=2, random_state=42)
# X_2d = tsne.fit_transform(X)

# plt.figure(figsize=(12, 10))
# scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=y, cmap='tab10', alpha=0.6)
# plt.colorbar(scatter)
# plt.title('Embeddings Visualization (t-SNE)')
# plt.xlabel('t-SNE 1')
# plt.ylabel('t-SNE 2')
# plt.savefig('../results/figures/embeddings_tsne.png', dpi=300, bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## Summary Metrics

# %%
# Example: Save metrics as JSON
# metrics = {
#     'train_accuracy': float(clf.score(X_train, y_train)),
#     'test_accuracy': float(clf.score(X_test, y_test)),
#     'n_samples': int(len(X)),
#     'n_features': int(X.shape[1]),
#     'model_type': type(clf).__name__
# }

# with open('../results/metrics.json', 'w') as f:
#     json.dump(metrics, f, indent=2)

# print("Metrics:")
# print(json.dumps(metrics, indent=2))

# %% [markdown]
# ## Summary Table

# %%
# Example: Create summary table
# summary_df = pd.DataFrame({
#     'Metric': ['Train Accuracy', 'Test Accuracy', 'N Samples', 'N Features'],
#     'Value': [metrics['train_accuracy'], metrics['test_accuracy'], 
#               metrics['n_samples'], metrics['n_features']]
# })

# summary_df.to_csv('../results/tables/summary.csv', index=False)
# display(summary_df)

# %% [markdown]
# ## Conclusions
#
# **TODO**: Write your conclusions and next steps here.
#
# - Key findings:
# - Limitations:
# - Future work:
